# %% [markdown]
# # PHP - Pulsating Heat Pipe [DI, 60FR, Heat Inputs]

# %%
from PyPulseHeatPipe import PulseHeatPipe
from PyPulseHeatPipe import DataVisualisation

# %%
d_40w = 'data/di_heat_inputs_6ofr/40w/'
s_40w = 'di_60fr_40w'
d_60w = 'data/di_heat_inputs_6ofr/60w/'
s_60w = 'di_60fr_60w'
d_80w = 'data/di_heat_inputs_6ofr/80w/'
s_80w = 'di_60fr_80w'
d_100w = 'data/di_heat_inputs_6ofr/100w/'
s_100w = 'di_60fr_100w'
d_120w = 'data/di_heat_inputs_6ofr/120w/'
s_120w = 'di_60fr_120w'

# %%
analysis_40w = PulseHeatPipe(datapath=d_40w, sample=s_40w)
analysis_60w = PulseHeatPipe(datapath=d_60w, sample=s_60w)
analysis_80w = PulseHeatPipe(datapath=d_80w, sample=s_80w)
analysis_100w = PulseHeatPipe(datapath=d_100w, sample=s_100w)
analysis_120w = PulseHeatPipe(datapath=d_120w, sample=s_120w)
# Out:
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/40w/
#
# Sample name saved as: di_60fr_40w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/60w/
#
# Sample name saved as: di_60fr_60w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/80w/
#
# Sample name saved as: di_60fr_80w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/100w/
#
# Sample name saved as: di_60fr_100w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/120w/
#
# Sample name saved as: di_60fr_120w

# %%
df_40w, df_conv_40w = analysis_40w.data_etl(name='di_*')
df_60w, df_conv_60w = analysis_60w.data_etl(name='di_*')
df_80w, df_conv_80w = analysis_80w.data_etl(name='di_*')
df_100w, df_conv_100w = analysis_100w.data_etl(name='di_*')
df_120w, df_conv_120w = analysis_120w.data_etl(name='di_*')
# Out:
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr/40w/di_60fr_40w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr/40w/'di_60fr_40w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr/60w/di_60fr_60w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr/60w/'di_60fr_60w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr/80w/di_60fr_80w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr/80w/'di_60fr_80w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr/100w/di_60fr_100w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr/100w/'di_60fr_100w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr/120w/di_60fr_120w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr/120w/'di_60fr_120w_combined_converted_data.csv' ###

# %%
df_conv_40w
df_conv_60w
df_conv_80w
df_conv_100w
df_conv_120w
# Out:
#        t(min)   Te[K]   Tc[K]  dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 0    00:00:00  307.75  307.40   0.35  0.479960    60  0.005833     90     0
# 1    00:00:05  307.95  307.40   0.55  0.479960    60  0.009167     90     0
# 2    00:00:10  307.75  307.40   0.35  0.479960    60  0.005833     90     0
# 3    00:00:15  307.95  307.40   0.55  0.479960    60  0.009167     90     0
# 4    00:00:20  307.75  307.15   0.60  0.479960    60  0.010000     90     0
# ..        ...     ...     ...    ...       ...   ...       ...    ...   ...
# 596  00:49:40  388.75  370.65  18.10  3.219867    60  0.301667     90     0
# 597  00:49:45  388.55  371.40  17.15  3.219867    60  0.285833     90     0
# 598  00:49:50  388.15  371.65  16.50  3.219867    60  0.275000     90     0
# 599  00:49:55  388.15  371.40  16.75  3.219867    60  0.279167     90     0
# 600  00:50:00  387.95  371.40  16.55  3.219867    60  0.275833     90     0
#
#      phase
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 596      1
# 597      1
# 598      1
# 599      1
# 600      1
#
# [601 rows x 10 columns]

# %%
df_gfe_40w = analysis_40w.gibbs_fe(df_conv_40w)
df_gfe_60w = analysis_60w.gibbs_fe(df_conv_60w)
df_gfe_80w = analysis_80w.gibbs_fe(df_conv_80w)
df_gfe_100w = analysis_100w.gibbs_fe(df_conv_100w)
df_gfe_120w = analysis_120w.gibbs_fe(df_conv_120w)
# Out:
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr/40w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr/60w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr/80w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr/100w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr/120w/'gfe_combined.csv

# %%
df_gfe_40w
df_gfe_60w
df_gfe_80w
df_gfe_100w
df_gfe_120w
# Out:
#        t(min)   Te[K]   Tc[K]  dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 0    00:00:00  307.75  307.40   0.35  0.479960    60  0.005833     90     0
# 1    00:00:05  307.95  307.40   0.55  0.479960    60  0.009167     90     0
# 2    00:00:10  307.75  307.40   0.35  0.479960    60  0.005833     90     0
# 3    00:00:15  307.95  307.40   0.55  0.479960    60  0.009167     90     0
# 4    00:00:20  307.75  307.15   0.60  0.479960    60  0.010000     90     0
# ..        ...     ...     ...    ...       ...   ...       ...    ...   ...
# 596  00:49:40  388.75  370.65  18.10  3.219867    60  0.301667     90     0
# 597  00:49:45  388.55  371.40  17.15  3.219867    60  0.285833     90     0
# 598  00:49:50  388.15  371.65  16.50  3.219867    60  0.275000     90     0
# 599  00:49:55  388.15  371.40  16.75  3.219867    60  0.279167     90     0
# 600  00:50:00  387.95  371.40  16.55  3.219867    60  0.275833     90     0
#
#      phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0        1    -1878.169624    -1876.033607   -2.136017
# 1        1    -1879.390206    -1876.033607   -3.356599
# 2        1    -1878.169624    -1876.033607   -2.136017
# 3        1    -1879.390206    -1876.033607   -3.356599
# 4        1    -1878.169624    -1874.507880   -3.661744
# ..     ...             ...             ...         ...
# 596      1     3779.386144     3603.419870  175.966275
# 597      1     3777.441766     3610.711290  166.730476
# 598      1     3773.553008     3613.141763  160.411245
# 599      1     3773.553008     3610.711290  162.841718
# 600      1     3771.608629     3610.711290  160.897339
#
# [601 rows x 13 columns]

# %%
visual_40w = DataVisualisation(datapath=d_40w, sample=s_40w)
visual_60w = DataVisualisation(datapath=d_60w, sample=s_60w)
visual_80w = DataVisualisation(datapath=d_80w, sample=s_80w)
visual_100w = DataVisualisation(datapath=d_100w, sample=s_100w)
visual_120w = DataVisualisation(datapath=d_120w, sample=s_120w)
# Out:
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/40w/
#
# Sample name saved as: di_60fr_40w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/60w/
#
# Sample name saved as: di_60fr_60w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/80w/
#
# Sample name saved as: di_60fr_80w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/100w/
#
# Sample name saved as: di_60fr_100w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr/120w/
#
# Sample name saved as: di_60fr_120w

# %%
visual_40w.plot_all_data(df_gfe_40w)
visual_60w.plot_all_data(df_gfe_60w)
visual_80w.plot_all_data(df_gfe_80w)
visual_100w.plot_all_data(df_gfe_100w)
visual_120w.plot_all_data(df_gfe_120w)

# %%
visual_40w.plot_Te_Tc(df_gfe_40w)
visual_60w.plot_Te_Tc(df_gfe_60w)
visual_80w.plot_Te_Tc(df_gfe_80w)
visual_100w.plot_Te_Tc(df_gfe_100w)
visual_120w.plot_Te_Tc(df_gfe_120w)

# %%
#data = analysis.data_chop(df_gfe,300,400)

# %%
df_gfe_40w['Te[K]'] = df_gfe_40w['Te[K]'].round(0)
df_gfe_60w['Te[K]'] = df_gfe_60w['Te[K]'].round(0)
df_gfe_80w['Te[K]'] = df_gfe_80w['Te[K]'].round(0)
df_gfe_100w['Te[K]'] = df_gfe_100w['Te[K]'].round(0)
df_gfe_120w['Te[K]'] = df_gfe_120w['Te[K]'].round(0)

# %%
df_mean_40w, df_std_40w = analysis_40w.data_stat(df_gfe_40w.drop('t(min)', axis=1))
df_mean_60w, df_std_60w = analysis_60w.data_stat(df_gfe_60w.drop('t(min)', axis=1))
df_mean_80w, df_std_80w = analysis_80w.data_stat(df_gfe_80w.drop('t(min)', axis=1))
df_mean_100w, df_std_100w = analysis_100w.data_stat(df_gfe_100w.drop('t(min)', axis=1))
df_mean_120w, df_std_120w = analysis_120w.data_stat(df_gfe_120w.drop('t(min)', axis=1))
# Out:
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr/40w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr/60w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr/80w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr/100w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr/120w/'combined_mean.csv' and 'combined_std.csv'

# %%
df_mean_40w = analysis_40w.data_chop(df_mean_40w, Tmin=300, Tmax=345)
df_mean_60w = analysis_60w.data_chop(df_mean_60w, Tmin=300, Tmax=345)
df_mean_80w = analysis_80w.data_chop(df_mean_80w, Tmin=300, Tmax=345)
df_mean_100w = analysis_100w.data_chop(df_mean_100w, Tmin=300, Tmax=345)
df_mean_120w = analysis_120w.data_chop(df_mean_120w, Tmin=300, Tmax=345)
# Out:
# Optimal range of temperature(Te) for data selection: [Tmin:309.0, Tmax:344]
# Optimal range of temperature(Te) for data selection: [Tmin:307.0, Tmax:354]
# Optimal range of temperature(Te) for data selection: [Tmin:306.0, Tmax:370]
# Optimal range of temperature(Te) for data selection: [Tmin:304.0, Tmax:376]
# Optimal range of temperature(Te) for data selection: [Tmin:308.0, Tmax:389]

# %%
df_std_100w
# Out:
#     Te[K]     Tc[K]     dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  phase  \
# 0   304.0  0.000000  0.084327  0.000000   0.0  0.000843    0.0   0.0    0.0
# 1   305.0  0.188982  0.106904  0.000000   0.0  0.001069    0.0   0.0    0.0
# 2   306.0  0.000000  0.260768  0.000000   0.0  0.002608    0.0   0.0    0.0
# 3   307.0  0.000000  0.412311  0.000000   0.0  0.004123    0.0   0.0    0.0
# 4   308.0  0.125000  0.103078  0.000000   0.0  0.001031    0.0   0.0    0.0
# ..    ...       ...       ...       ...   ...       ...    ...   ...    ...
# 66  371.0  0.877971  0.879464  0.047154   0.0  0.008795    0.0   0.0    0.0
# 67  372.0  0.686277  0.754790  0.045040   0.0  0.007548    0.0   0.0    0.0
# 68  373.0  0.758678  0.676964  0.034051   0.0  0.006770    0.0   0.0    0.0
# 69  374.0  0.802296  0.737377  0.033415   0.0  0.007374    0.0   0.0    0.0
# 70  375.0  0.830122  0.881709  0.033313   0.0  0.008817    0.0   0.0    0.0
#
#     GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0         0.619479        0.000000    0.619479
# 1         1.634800        1.388285    0.785333
# 2         1.915632        0.000000    1.915632
# 3         3.028880        0.000000    3.028880
# 4         1.406674        0.918264    0.757220
# ..             ...             ...         ...
# 66       78.494434       74.368960    6.157117
# 67       72.648476       68.782092    5.720932
# 68       54.338693       53.625966    3.328224
# 69       51.706696       51.419839    3.822861
# 70       51.123628       48.563522    5.943205
#
# [68 rows x 12 columns]

# %%
df_mean_40w
df_mean_60w
df_mean_80w
df_mean_100w
df_mean_120w
# Out:
#     Te[K]       Tc[K]      dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 0   308.0  307.400000   0.563333  0.479960  60.0  0.009389   90.0   0.0
# 1   309.0  307.441667   1.541667  0.479960  60.0  0.025694   90.0   0.0
# 2   310.0  307.712500   2.387500  0.479960  60.0  0.039792   90.0   0.0
# 3   311.0  307.650000   3.300000  0.479960  60.0  0.055000   90.0   0.0
# 4   312.0  308.066667   3.883333  0.479960  60.0  0.064722   90.0   0.0
# ..    ...         ...        ...       ...   ...       ...    ...   ...
# 77  385.0  366.555172  18.512069  2.808980  60.0  0.308534   90.0   0.0
# 78  386.0  367.720312  18.148438  2.924119  60.0  0.302474   90.0   0.0
# 79  387.0  369.029630  17.979630  3.009194  60.0  0.299660   90.0   0.0
# 80  388.0  369.958140  17.926744  3.125216  60.0  0.298779   90.0   0.0
# 81  389.0  371.435714  17.228571  3.202354  60.0  0.287143   90.0   0.0
#
#     phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0     1.0    -1879.471578    -1876.033607   -3.437971
# 1     1.0    -1885.696543    -1876.287895   -9.408648
# 2     1.0    -1892.511456    -1877.940765  -14.570690
# 3     1.0    -1897.698927    -1877.559334  -20.139593
# 4     1.0    -1903.801834    -1880.102211  -23.699622
# ..    ...             ...             ...         ...
# 77    1.0     3304.669472     3146.199941  158.469531
# 78    1.0     3441.802169     3280.004429  161.797740
# 79    1.0     3543.899707     3379.327133  164.572574
# 80    1.0     3673.053457     3503.643889  169.409568
# 81    1.0     3760.736807     3594.043709  166.693098
#
# [82 rows x 12 columns]

# %%
import pandas as pd
import numpy as np

def data_thermal_resistance_max(df_mean: pd.DataFrame, df_std: pd.DataFrame, Tmax: float = None):
    """ 
    data_property_max calculates the maximum thermal resistance value of measured thermal properties for the given experiment data.

    use: analysis.data_property_max(df_mean, df_std)
    """

    # Merge the mean and std dataframes on 'Te[K]'
    df = pd.merge(left=df_mean, right=df_std, on=['Te[K]'], suffixes=['_mean', '_std'])
    df['Te[K]'] = df['Te[K]'].round(decimals=0)
    
    # Check if Tmax is provided
    if Tmax is not None:
        if Tmax in df['Te[K]'].values:
            max_row = df[df['Te[K]'] == Tmax]
        else:
            # Find the closest Tmax value in the dataframe
            closest_Tmax = df['Te[K]'].iloc[(df['Te[K]'] - Tmax).abs().argmin()]
            max_row = df[df['Te[K]'] == closest_Tmax]
            print(f"Tmax {Tmax} not found. Using closest value: {closest_Tmax}")
    else:
        # Find the row with the maximum 'TR[K/W]_mean'
        max_row = df[df['TR[K/W]_mean'] == df['TR[K/W]_mean'].max()]
    
    # Extract the values from the selected row
    max_TR_mean = max_row['TR[K/W]_mean'].values[0]
    max_TR_std = max_row['TR[K/W]_std'].values[0]
    max_T = max_row['Te[K]'].values[0]
    max_Q = max_row['Q[W]_mean'].values[0]
    
    # Print the results
    print(f"""
        T_max[K]            : {np.round(max_T, 4)}
        TR[K/W] mean        : {np.round(max_TR_mean, 4)}
        TR[K/W] std         : {np.round(max_TR_std, 4)}
        Q[W]                : {np.round(max_Q, 0)}""")
    
    return max_TR_mean, max_TR_std, max_T

# %%
max_TR_mean_100W, max_TR_std_100W, max_T = data_thermal_resistance_max(df_mean=df_mean_100w, df_std=df_std_100w, Tmax=333)
# Out:
#         T_max[K]            : 333.0
#         TR[K/W] mean        : 0.1882
#         TR[K/W] std         : 0.0004
#         Q[W]                : 100.0

# %%
max_TR_mean_120W, max_TR_std_120W, max_T = data_thermal_resistance_max(df_mean=df_mean_120w, df_std=df_std_120w)
# Out:
#             T_max[K]            : 345.0
#             TR[K/W] mean        : 0.4192
#             TR[K/W] std         : 0.0035
#             Q[W]                : 60.0

# %%
max_TR_mean_80W, max_TR_std_80W, max_T = data_thermal_resistance_max(df_mean=df_mean_80w, df_std=df_std_80w)
# Out:
#             T_max[K]            : 345.0
#             TR[K/W] mean        : 0.2929
#             TR[K/W] std         : 0.0016
#             Q[W]                : 80.0

# %%
max_TR_mean_60W, max_TR_std_60W, max_T = data_thermal_resistance_max(df_mean=df_mean_60w, df_std=df_std_60w)
# Out:
#             T_max[K]            : 345.0
#             TR[K/W] mean        : 0.3645
#             TR[K/W] std         : 0.0047
#             Q[W]                : 60.0

# %%
max_TR_mean_40W, max_TR_std_40W, max_T = data_thermal_resistance_max(df_mean=df_mean_40w, df_std=df_std_40w)
# Out:
#             T_max[K]            : 344.0
#             TR[K/W] mean        : 0.5073
#             TR[K/W] std         : 0.0072
#             Q[W]                : 40.0

# %%
analysis_60w.data_property_avg(df_mean_60w, df_std_60w)
# Out:
# Tc  average:     314.1021 +- 0.2765 [K]
# P   average:     0.4832 +- 0.0053 [bar]
# dT  average:     11.8611 +- 0.355 [K]
# TR  average:     0.1977 +- 0.0059 [K/W]
# GFE average:     -1927.4732 +- 23.8741 [KJ/mol]

# %%
analysis_80w.data_property_avg(df_mean_80w, df_std_80w)
# Out:
# Tc  average:     321.679 +- 0.6563 [K]
# P   average:     0.7125 +- 0.0179 [bar]
# dT  average:     16.269 +- 0.6873 [K]
# TR  average:     0.2034 +- 0.0086 [K/W]
# GFE average:     -1098.6786 +- 52.9791 [KJ/mol]

# %%
analysis_100w.data_property_avg(df_mean_100w, df_std_100w)
# Out:
# Tc  average:     322.7313 +- 0.6379 [K]
# P   average:     0.8874 +- 0.0153 [bar]
# dT  average:     17.2458 +- 0.6434 [K]
# TR  average:     0.1725 +- 0.0064 [K/W]
# GFE average:     -659.4211 +- 39.3353 [KJ/mol]

# %%
analysis_120w.data_property_avg(df_mean_120w, df_std_120w)
# Out:
# Tc  average:     329.6292 +- 0.4073 [K]
# P   average:     1.1707 +- 0.018 [bar]
# dT  average:     18.7974 +- 0.3996 [K]
# TR  average:     0.3133 +- 0.0067 [K/W]
# GFE average:     -48.6626 +- 34.183 [KJ/mol]

# %%
analysis_40w.best_TP(df_mean_40w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-108.6536]
# Tc optimal:        315.2594[K]
# Te optimal:        330.0[K]
# P  optimal:        0.4133[bar]
# dT optimal:        14.7906[K]
# TR optimal:        0.3698[K/W]
# GFE optimal:       dG(330.0, 0.4133) = -2315.9313 [KJ/mol]

# %%
analysis_60w.best_TP(df_mean_60w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-90.9897]
# Tc optimal:        316.5667[K]
# Te optimal:        332.0[K]
# P  optimal:        0.4911[bar]
# dT optimal:        15.3833[K]
# TR optimal:        0.2564[K/W]
# GFE optimal:       dG(332.0, 0.4911) = -1873.0438 [KJ/mol]

# %%
analysis_80w.best_TP(df_mean_80w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-105.8563]
# Tc optimal:        318.75[K]
# Te optimal:        340.0[K]
# P  optimal:        0.5466[bar]
# dT optimal:        21.08[K]
# TR optimal:        0.2635[K/W]
# GFE optimal:       dG(340.0, 0.5466) = -1600.6494 [KJ/mol]

# %%
analysis_100w.best_TP(df_mean_100w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-96.478]
# Tc optimal:        312.4833[K]
# Te optimal:        330.0[K]
# P  optimal:        0.5133[bar]
# dT optimal:        17.4[K]
# TR optimal:        0.174[K/W]
# GFE optimal:       dG(330.0, 0.5133) = -1732.6297 [KJ/mol]

# %%
analysis_120w.best_TP(df_mean_120w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-97.0433]
# Tc optimal:        315.525[K]
# Te optimal:        335.0[K]
# P  optimal:        0.5466[bar]
# dT optimal:        19.325[K]
# TR optimal:        0.3221[K/W]
# GFE optimal:       dG(335.0, 0.5466) = -1584.4546 [KJ/mol]

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'Tc[K]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'Tc[K]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'Tc[K]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'Tc[K]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'Tc[K]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'dT[K]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'dT[K]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'dT[K]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'dT[K]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'dT[K]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'P[bar]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'P[bar]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'P[bar]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'P[bar]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'P[bar]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'TR[K/W]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'TR[K/W]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'TR[K/W]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'TR[K/W]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'TR[K/W]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'GFE_Tc[KJ/mol]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'GFE_Tc[KJ/mol]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'GFE_Tc[KJ/mol]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'GFE_Tc[KJ/mol]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'GFE_Tc[KJ/mol]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'GFE_Te[KJ/mol]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'GFE_Te[KJ/mol]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'GFE_Te[KJ/mol]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'GFE_Te[KJ/mol]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'GFE_Te[KJ/mol]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'dG[KJ/mol]','.r','g')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'dG[KJ/mol]','.r','g')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'dG[KJ/mol]','.r','g')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'dG[KJ/mol]','.r','g')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'dG[KJ/mol]','.r','g')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# plotting Thermal resistance
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_mean_40w['Q[W]'], y=df_mean_40w['TR[K/W]'], label='DI-Water 40FR')
sns.scatterplot(x=df_mean_60w['Q[W]'], y=df_mean_60w['TR[K/W]'], label='DI-Water 60FR')
sns.scatterplot(x=df_mean_80w['Q[W]'], y=df_mean_80w['TR[K/W]'], label='DI-Water 80FR')
sns.scatterplot(x=df_mean_100w['Q[W]'], y=df_mean_100w['TR[K/W]'], label='DI-Water 100FR')
sns.scatterplot(x=df_mean_120w['Q[W]'], y=df_mean_120w['TR[K/W]'], label='DI-Water 120FR')
plt.legend()

# %%
# find minimum value from dG and its index value
TR_40W_opt = df_mean_40w[df_mean_40w['dG[KJ/mol]'] == df_mean_40w['dG[KJ/mol]'].min()]

# %%
TR_40W_opt
# Out:
#     Te[K]       Tc[K]      dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 21  330.0  315.259375  14.790625  0.413299  40.0  0.369766   90.0   0.0
#
#     phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 21    1.0    -2424.584866    -2315.931252 -108.653615

# %%
TR_40W_opt_idx = TR_40W_opt.index

# %%
TR_40W_opt_idx
# Out:
# Index([21], dtype='int64')

# %%
# average value of TR
TR_40W_avg = df_mean_40w['TR[K/W]'].mean()
TR_40W_std = df_mean_40w['TR[K/W]'].std()

# %%
print(f'Average TR[K/W]: Mean {round(TR_40W_avg,4)} +- Std {round(TR_40W_std,4)}')
# Out:
# Average TR[K/W]: Mean 0.3097 +- Std 0.1375

# %%
# critical value
TR_40W_crt = df_mean_40w[(df_mean_40w['dG[KJ/mol]'] > df_mean_40w['dG[KJ/mol]'].min()) & (df_mean_40w['Te[K]'] == df_mean_40w['Te[K]'].max())]

# %%
TR_40W_crt
# Out:
#     Te[K]       Tc[K]      dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 35  344.0  323.461024  20.293701  0.597273  40.0  0.507343   90.0   0.0
#
#     phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 35    1.0    -1474.033075    -1387.017761  -87.015313

# %%
# df making of all point
# TR_mean = [TR_40W_avg,TR_60W_avg, ... ... ]
# TR_crt = [TR_40W_crt['TR[K/W]'], TR_60W_crt['TR[K/W]'], TR_60W_crt['TR[K/W]']]
# TR_opt = [TR_40W_opt['TR[K/W]']]  

TR_mean = [TR_40W_avg]
TR_crt = [TR_40W_crt['TR[K/W]']]
TR_opt = [TR_40W_opt['TR[K/W]']]
#Q = [40, 60, 80, 100, 120]
Q = [40]

# %%
plt.figure(figsize=(7,5))
plt.scatter(x=Q, y=TR_mean, label='40W_mean')
plt.scatter(x=Q, y=TR_opt, label='40W_opt')
plt.scatter(x=Q, y=TR_crt, label='40W_crt')
plt.errorbar(x=Q, y=TR_mean, yerr=TR_40W_std, label='EU', capsize=5)

plt.ylim(0, 0.55)
plt.xlim(20, 140)
plt.ylabel('TR[K/W]')
plt.xlabel('Q[W]')
plt.title('title')
plt.legend()
plt.show()
