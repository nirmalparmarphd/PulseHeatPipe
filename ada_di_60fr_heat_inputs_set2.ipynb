# %% [markdown]
# # PHP - Pulsating Heat Pipe [DI, 60FR, Heat Inputs]

# %%
from PyPulseHeatPipe import PulseHeatPipe
from PyPulseHeatPipe import DataVisualisation

# %%
d_40w = 'data/di_heat_inputs_6ofr_set2/40w/'
s_40w = 'di_60fr_40w'
d_60w = 'data/di_heat_inputs_6ofr_set2/60w/'
s_60w = 'di_60fr_60w'
d_80w = 'data/di_heat_inputs_6ofr_set2/80w/'
s_80w = 'di_60fr_80w'
d_100w = 'data/di_heat_inputs_6ofr_set2/100w/'
s_100w = 'di_60fr_100w'
d_120w = 'data/di_heat_inputs_6ofr_set2/120w/'
s_120w = 'di_60fr_120w'

# %%
analysis_40w = PulseHeatPipe(datapath=d_40w, sample=s_40w)
analysis_60w = PulseHeatPipe(datapath=d_60w, sample=s_60w)
analysis_80w = PulseHeatPipe(datapath=d_80w, sample=s_80w)
analysis_100w = PulseHeatPipe(datapath=d_100w, sample=s_100w)
analysis_120w = PulseHeatPipe(datapath=d_120w, sample=s_120w)
# Out:
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/40w/
#
# Sample name saved as: di_60fr_40w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/60w/
#
# Sample name saved as: di_60fr_60w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/80w/
#
# Sample name saved as: di_60fr_80w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/100w/
#
# Sample name saved as: di_60fr_100w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/120w/
#
# Sample name saved as: di_60fr_120w

# %%
df_40w, df_conv_40w = analysis_40w.data_etl(name='*')
df_60w, df_conv_60w = analysis_60w.data_etl(name='*')
df_80w, df_conv_80w = analysis_80w.data_etl(name='*')
df_100w, df_conv_100w = analysis_100w.data_etl(name='*')
df_120w, df_conv_120w = analysis_120w.data_etl(name='*')
# Out:
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr_set2/40w\\di_60fr_40w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr_set2/40w/'di_60fr_40w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr_set2/60w\\di_60fr_60w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr_set2/60w/'di_60fr_60w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr_set2/80w\\di_60fr_80w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr_set2/80w/'di_60fr_80w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr_set2/100w\\di_60fr_100w.xlsx']
# ### Compiled and converted data is saved at: data/di_heat_inputs_6ofr_set2/100w/'di_60fr_100w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/di_heat_inputs_6ofr_set2/120w\\di_60fr_120w.xlsx']
# ...

# %%
df_conv_40w
df_conv_60w
df_conv_80w
df_conv_100w
df_conv_120w
# Out:
#                   t(min)   Te[K]   Tc[K]  dT[K]    P[bar]  Q[W]   TR[K/W]  \
# 0               00:00:00  303.55  302.90   0.65  0.379969   120  0.005417
# 1               00:00:05  303.55  302.65   0.90  0.379969   120  0.007500
# 2               00:00:10  303.55  302.65   0.90  0.379969   120  0.007500
# 3               00:00:15  303.55  302.65   0.90  0.379969   120  0.007500
# 4               00:00:20  303.55  302.65   0.90  0.379969   120  0.007500
# ..                   ...     ...     ...    ...       ...   ...       ...
# 715  1900-01-04 19:50:00  385.35  362.40  22.95  1.405537   120  0.191250
# 716  1900-01-04 20:50:00  385.75  362.15  23.60  1.405537   120  0.196667
# 717  1900-01-04 21:50:00  385.35  362.90  22.45  1.454573   120  0.187083
# 718  1900-01-04 22:50:00  385.55  362.40  23.15  1.454573   120  0.192917
# 719  1900-01-04 23:50:00  385.75  362.65  23.10  1.454573   120  0.192500
#
#      alpha  beta  phase
# 0       90     0      1
# 1       90     0      1
# ...

# %%
df_gfe_40w = analysis_40w.gibbs_fe(df_conv_40w)
df_gfe_60w = analysis_60w.gibbs_fe(df_conv_60w)
df_gfe_80w = analysis_80w.gibbs_fe(df_conv_80w)
df_gfe_100w = analysis_100w.gibbs_fe(df_conv_100w)
df_gfe_120w = analysis_120w.gibbs_fe(df_conv_120w)
# Out:
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr_set2/40w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr_set2/60w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr_set2/80w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr_set2/100w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/di_heat_inputs_6ofr_set2/120w/'gfe_combined.csv

# %%
df_gfe_40w
df_gfe_60w
df_gfe_80w
df_gfe_100w
df_gfe_120w
# Out:
#                   t(min)   Te[K]   Tc[K]  dT[K]    P[bar]  Q[W]   TR[K/W]  \
# 0               00:00:00  303.55  302.90   0.65  0.379969   120  0.005417
# 1               00:00:05  303.55  302.65   0.90  0.379969   120  0.007500
# 2               00:00:10  303.55  302.65   0.90  0.379969   120  0.007500
# 3               00:00:15  303.55  302.65   0.90  0.379969   120  0.007500
# 4               00:00:20  303.55  302.65   0.90  0.379969   120  0.007500
# ..                   ...     ...     ...    ...       ...   ...       ...
# 715  1900-01-04 19:50:00  385.35  362.40  22.95  1.405537   120  0.191250
# 716  1900-01-04 20:50:00  385.75  362.15  23.60  1.405537   120  0.196667
# 717  1900-01-04 21:50:00  385.35  362.90  22.45  1.454573   120  0.187083
# 718  1900-01-04 22:50:00  385.55  362.40  23.15  1.454573   120  0.192917
# 719  1900-01-04 23:50:00  385.75  362.65  23.10  1.454573   120  0.192500
#
#      alpha  beta  phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# ...

# %%
visual_40w = DataVisualisation(datapath=d_40w, sample=s_40w)
visual_60w = DataVisualisation(datapath=d_60w, sample=s_60w)
visual_80w = DataVisualisation(datapath=d_80w, sample=s_80w)
visual_100w = DataVisualisation(datapath=d_100w, sample=s_100w)
visual_120w = DataVisualisation(datapath=d_120w, sample=s_120w)
# Out:
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/40w/
#
# Sample name saved as: di_60fr_40w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/60w/
#
# Sample name saved as: di_60fr_60w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/80w/
#
# Sample name saved as: di_60fr_80w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/100w/
#
# Sample name saved as: di_60fr_100w
# Datapath loaded for working directory: data/di_heat_inputs_6ofr_set2/120w/
#
# Sample name saved as: di_60fr_120w

# %%
visual_40w.plot_all_data(df_gfe_40w)
visual_60w.plot_all_data(df_gfe_60w)
visual_80w.plot_all_data(df_gfe_80w)
visual_100w.plot_all_data(df_gfe_100w)
visual_120w.plot_all_data(df_gfe_120w)

# %%
visual_40w.plot_Te_Tc(df_gfe_40w)
visual_60w.plot_Te_Tc(df_gfe_60w)
visual_80w.plot_Te_Tc(df_gfe_80w)
visual_100w.plot_Te_Tc(df_gfe_100w)
visual_120w.plot_Te_Tc(df_gfe_120w)

# %%
df_selected_40w = analysis_40w.data_chop(df_gfe_40w,310,345)
df_selected_60w = analysis_60w.data_chop(df_gfe_60w,310,345)
df_selected_80w = analysis_80w.data_chop(df_gfe_80w,310,345)
df_selected_100w = analysis_100w.data_chop(df_gfe_100w,310,345)
df_selected_120w = analysis_120w.data_chop(df_gfe_120w,310,345)
# Out:
# Optimal range of temperature(Te) for data selection: [Tmin:301.15, Tmax:341]
# Optimal range of temperature(Te) for data selection: [Tmin:301.75, Tmax:350]
# Optimal range of temperature(Te) for data selection: [Tmin:300.15, Tmax:365]
# Optimal range of temperature(Te) for data selection: [Tmin:302.75, Tmax:381]
# Optimal range of temperature(Te) for data selection: [Tmin:303.55, Tmax:389]

# %%
df_gfe_40w['Te[K]'] = df_gfe_40w['Te[K]'].round(0)
df_gfe_60w['Te[K]'] = df_gfe_60w['Te[K]'].round(0)
df_gfe_80w['Te[K]'] = df_gfe_80w['Te[K]'].round(0)
df_gfe_100w['Te[K]'] = df_gfe_100w['Te[K]'].round(0)
df_gfe_120w['Te[K]'] = df_gfe_120w['Te[K]'].round(0)

# %%
df_mean_40w, df_std_40w = analysis_40w.data_stat(df_selected_40w.drop('t(min)', axis=1))
df_mean_60w, df_std_60w = analysis_60w.data_stat(df_selected_60w.drop('t(min)', axis=1))
df_mean_80w, df_std_80w = analysis_80w.data_stat(df_selected_80w.drop('t(min)', axis=1))
df_mean_100w, df_std_100w = analysis_100w.data_stat(df_selected_100w.drop('t(min)', axis=1))
df_mean_120w, df_std_120w = analysis_120w.data_stat(df_selected_120w.drop('t(min)', axis=1))
# Out:
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr_set2/40w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr_set2/60w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr_set2/80w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr_set2/100w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/di_heat_inputs_6ofr_set2/120w/'combined_mean.csv' and 'combined_std.csv'

# %%
df_mean_40w
#df_mean_60w
#df_mean_80w
#df_mean_100w
#df_mean_120w
# Out:
#       Te[K]       Tc[K]      dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 0    310.15  303.900000   6.250000  0.413299  40.0  0.156250   90.0   0.0
# 1    310.40  303.900000   6.500000  0.413299  40.0  0.162500   90.0   0.0
# 2    310.65  303.900000   6.750000  0.413299  40.0  0.168750   90.0   0.0
# 3    310.90  303.900000   7.000000  0.413299  40.0  0.175000   90.0   0.0
# 4    311.40  304.337500   7.062500  0.413299  40.0  0.176563   90.0   0.0
# ..      ...         ...        ...       ...   ...       ...    ...   ...
# 104  339.65  315.926786  23.723214  0.566858  40.0  0.593080   90.0   0.0
# 105  339.90  315.918939  23.981061  0.572377  40.0  0.599527   90.0   0.0
# 106  340.15  316.066667  24.083333  0.576249  40.0  0.602083   90.0   0.0
# 107  340.40  316.161364  24.238636  0.579952  40.0  0.605966   90.0   0.0
# 108  340.65  316.087500  24.562500  0.579952  40.0  0.614063   90.0   0.0
#
#      phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# ...

# %% [markdown]
# #Average values

# %%
analysis_40w.data_property_avg(df_mean_40w, df_std_40w)
# Out:
# Tc  average:     310.2535 +- 0.1381 [K]
# P   average:     0.4771 +- 0.0015 [bar]
# dT  average:     15.7543 +- 0.1381 [K]
# TR  average:     0.3939 +- 0.0035 [K/W]
# GFE average:     -1919.6262 +- 8.1391 [KJ/mol]

# %%
analysis_60w.data_property_avg(df_mean_60w, df_std_60w)
# Out:
# Tc  average:     312.1937 +- 0.0936 [K]
# P   average:     0.5094 +- 0.0016 [bar]
# dT  average:     16.9349 +- 0.0936 [K]
# TR  average:     0.2822 +- 0.0016 [K/W]
# GFE average:     -1778.6716 +- 7.6283 [KJ/mol]

# %%
analysis_80w.data_property_avg(df_mean_80w, df_std_80w)
# Out:
# Tc  average:     309.6774 +- 0.1909 [K]
# P   average:     0.5042 +- 0.0021 [bar]
# dT  average:     18.5486 +- 0.1909 [K]
# TR  average:     0.2319 +- 0.0024 [K/W]
# GFE average:     -1790.839 +- 10.527 [KJ/mol]

# %%
analysis_100w.data_property_avg(df_mean_100w, df_std_100w)
# Out:
# Tc  average:     308.2782 +- 0.6839 [K]
# P   average:     0.4915 +- 0.0175 [bar]
# dT  average:     19.0671 +- 0.6839 [K]
# TR  average:     0.1907 +- 0.0068 [K/W]
# GFE average:     -1845.7728 +- 69.0333 [KJ/mol]

# %%
analysis_120w.data_property_avg(df_mean_120w, df_std_120w)
# Out:
# Tc  average:     308.8965 +- 0.3536 [K]
# P   average:     0.5199 +- 0.0 [bar]
# dT  average:     19.493 +- 0.3536 [K]
# TR  average:     0.1624 +- 0.0029 [K/W]
# GFE average:     -1811.0722 +- 1.9092 [KJ/mol]

# %% [markdown]
# #Lowest (optimal) values

# %%
analysis_40w.best_TP(df_mean_40w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-121.3564]
# Tc optimal:        314.4833[K]
# Te optimal:        338.65[K]
# P  optimal:        0.5466[bar]
# dT optimal:        24.1667[K]
# TR optimal:        0.6042[K/W]
# GFE optimal:       dG(338.65, 0.5466) = -1579.2237 [KJ/mol]

# %%
analysis_60w.best_TP(df_mean_60w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-110.7678]
# Tc optimal:        312.4[K]
# Te optimal:        330.55[K]
# P  optimal:        0.48[bar]
# dT optimal:        18.15[K]
# TR optimal:        0.3025[K/W]
# GFE optimal:       dG(330.55, 0.48) = -1906.5481 [KJ/mol]

# %%
analysis_80w.best_TP(df_mean_80w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-127.2456]
# Tc optimal:        309.9[K]
# Te optimal:        330.75[K]
# P  optimal:        0.48[bar]
# dT optimal:        20.85[K]
# TR optimal:        0.2606[K/W]
# GFE optimal:       dG(330.75, 0.48) = -1891.2909 [KJ/mol]

# %%
analysis_100w.best_TP(df_mean_100w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-134.182]
# Tc optimal:        310.15[K]
# Te optimal:        334.35[K]
# P  optimal:        0.5133[bar]
# dT optimal:        24.2[K]
# TR optimal:        0.242[K/W]
# GFE optimal:       dG(334.35, 0.5133) = -1719.6921 [KJ/mol]

# %%
analysis_120w.best_TP(df_mean_120w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-155.9293]
# Tc optimal:        312.4[K]
# Te optimal:        337.95[K]
# P  optimal:        0.48[bar]
# dT optimal:        25.55[K]
# TR optimal:        0.2129[K/W]
# GFE optimal:       dG(337.95, 0.48) = -1906.5481 [KJ/mol]

# %% [markdown]
# #Data Visualizations

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'Tc[K]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'Tc[K]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'Tc[K]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'Tc[K]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'Tc[K]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'dT[K]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'dT[K]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'dT[K]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'dT[K]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'dT[K]')

# %% [markdown]
# #Pressure (P)

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'P[bar]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'P[bar]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'P[bar]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'P[bar]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'P[bar]')

# %% [markdown]
# #Thermal Resistance (TR)

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'TR[K/W]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'TR[K/W]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'TR[K/W]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'TR[K/W]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'TR[K/W]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'GFE_Tc[KJ/mol]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'GFE_Tc[KJ/mol]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'GFE_Tc[KJ/mol]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'GFE_Tc[KJ/mol]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'GFE_Tc[KJ/mol]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'GFE_Te[KJ/mol]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'GFE_Te[KJ/mol]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'GFE_Te[KJ/mol]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'GFE_Te[KJ/mol]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'GFE_Te[KJ/mol]')

# %% [markdown]
# #Change in Gibbs free energy (dG)

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'dG[KJ/mol]','.r','g')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'dG[KJ/mol]','.r','g')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'dG[KJ/mol]','.r','g')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'dG[KJ/mol]','.r','g')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'dG[KJ/mol]','.r','g')

# %% [markdown]
# #Thermal Resistance (TR) vs Heat Inputs (Q)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# plotting Thermal resistance
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_mean_40w['Q[W]'], y=df_mean_40w['TR[K/W]'], label='DI-Water 40W')
sns.scatterplot(x=df_mean_60w['Q[W]'], y=df_mean_60w['TR[K/W]'], label='DI-Water 60W')
sns.scatterplot(x=df_mean_80w['Q[W]'], y=df_mean_80w['TR[K/W]'], label='DI-Water 80W')
sns.scatterplot(x=df_mean_100w['Q[W]'], y=df_mean_100w['TR[K/W]'], label='DI-Water 100W')
sns.scatterplot(x=df_mean_120w['Q[W]'], y=df_mean_120w['TR[K/W]'], label='DI-Water 120W')
plt.legend()

# %%
# find minimum value from dG and its index value
TR_40W_opt = df_mean_40w[df_mean_40w['dG[KJ/mol]'] == df_mean_40w['dG[KJ/mol]'].min()]
TR_60W_opt = df_mean_60w[df_mean_60w['dG[KJ/mol]'] == df_mean_60w['dG[KJ/mol]'].min()]
TR_80W_opt = df_mean_80w[df_mean_80w['dG[KJ/mol]'] == df_mean_80w['dG[KJ/mol]'].min()]
TR_100W_opt = df_mean_100w[df_mean_100w['dG[KJ/mol]'] == df_mean_100w['dG[KJ/mol]'].min()]
TR_120W_opt = df_mean_120w[df_mean_120w['dG[KJ/mol]'] == df_mean_120w['dG[KJ/mol]'].min()]

# %%
TR_40W_opt
TR_60W_opt
TR_80W_opt
TR_100W_opt
TR_120W_opt
# Out:
#      Te[K]  Tc[K]  dT[K]   P[bar]   Q[W]   TR[K/W]  alpha  beta  phase  \
# 54  337.95  312.4  25.55  0.47996  120.0  0.212917   90.0   0.0    1.0
#
#     GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 54    -2062.477415    -1906.548142 -155.929273

# %%
TR_40W_opt_idx = TR_40W_opt.index
TR_60W_opt_idx = TR_60W_opt.index
TR_80W_opt_idx = TR_80W_opt.index
TR_100W_opt_idx = TR_100W_opt.index
TR_120W_opt_idx = TR_120W_opt.index

# %%
TR_40W_opt_idx
# Out:
# Index([100], dtype='int64')

# %%
# average value of TR
TR_40W_avg = df_mean_40w['TR[K/W]'].mean()
TR_40W_std = df_mean_40w['TR[K/W]'].std()
TR_60W_avg = df_mean_60w['TR[K/W]'].mean()
TR_60W_std = df_mean_60w['TR[K/W]'].std()
TR_80W_avg = df_mean_80w['TR[K/W]'].mean()
TR_80W_std = df_mean_80w['TR[K/W]'].std()
TR_100W_avg = df_mean_100w['TR[K/W]'].mean()
TR_100W_std = df_mean_100w['TR[K/W]'].std()
TR_120W_avg = df_mean_120w['TR[K/W]'].mean()
TR_120W_std = df_mean_120w['TR[K/W]'].std()

# %%
print(f'Average TR[K/W]: Mean {round(TR_40W_avg,4)} +- Std {round(TR_40W_std,4)}')
print(f'Average TR[K/W]: Mean {round(TR_60W_avg,4)} +- Std {round(TR_60W_std,4)}')
print(f'Average TR[K/W]: Mean {round(TR_80W_avg,4)} +- Std {round(TR_80W_std,4)}')
print(f'Average TR[K/W]: Mean {round(TR_100W_avg,4)} +- Std {round(TR_100W_std,4)}')
print(f'Average TR[K/W]: Mean {round(TR_120W_avg,4)} +- Std {round(TR_120W_std,4)}')
# Out:
# Average TR[K/W]: Mean 0.3939 +- Std 0.1302
# Average TR[K/W]: Mean 0.2822 +- Std 0.0824
# Average TR[K/W]: Mean 0.2319 +- Std 0.0682
# Average TR[K/W]: Mean 0.1907 +- Std 0.0674
# Average TR[K/W]: Mean 0.1624 +- Std 0.0539

# %%
# critical value
TR_40W_crt = df_mean_40w[(df_mean_40w['dG[KJ/mol]'] > df_mean_40w['dG[KJ/mol]'].min()) & (df_mean_40w['Te[K]'] == df_mean_40w['Te[K]'].max())]
TR_60W_crt = df_mean_60w[(df_mean_60w['dG[KJ/mol]'] > df_mean_60w['dG[KJ/mol]'].min()) & (df_mean_60w['Te[K]'] == df_mean_60w['Te[K]'].max())]
TR_80W_crt = df_mean_80w[(df_mean_80w['dG[KJ/mol]'] > df_mean_80w['dG[KJ/mol]'].min()) & (df_mean_80w['Te[K]'] == df_mean_80w['Te[K]'].max())]
TR_100W_crt = df_mean_100w[(df_mean_100w['dG[KJ/mol]'] > df_mean_100w['dG[KJ/mol]'].min()) & (df_mean_100w['Te[K]'] == df_mean_100w['Te[K]'].max())]
TR_120W_crt = df_mean_120w[(df_mean_120w['dG[KJ/mol]'] > df_mean_120w['dG[KJ/mol]'].min()) & (df_mean_120w['Te[K]'] == df_mean_120w['Te[K]'].max())]

# %%
TR_40W_crt
# Out:
#       Te[K]     Tc[K]    dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  phase  \
# 108  340.65  316.0875  24.5625  0.579952  40.0  0.614063   90.0   0.0    1.0
#
#      GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 108    -1542.990866    -1431.733819 -111.257047

# %%
# df making of all point
di_TR_mean = [TR_40W_avg, TR_60W_avg, TR_80W_avg, TR_100W_avg, TR_120W_avg]
di_TR_crt = [TR_40W_crt['TR[K/W]'], TR_60W_crt['TR[K/W]'], TR_80W_crt['TR[K/W]'], TR_100W_crt['TR[K/W]'], TR_120W_crt['TR[K/W]']]
di_TR_opt = [TR_40W_opt['TR[K/W]'], TR_60W_opt['TR[K/W]'], TR_80W_opt['TR[K/W]'], TR_100W_opt['TR[K/W]'], TR_120W_opt['TR[K/W]']]
Q = [40, 60, 80, 100, 120]

# %%
plt.figure(figsize=(8,5))
plt.scatter(x=Q, y=di_TR_mean, label='DI_mean')
plt.scatter(x=Q, y=di_TR_opt, label='DI_opt')
plt.scatter(x=Q, y=di_TR_crt, label='DI_crt')
plt.errorbar(x=Q, y=di_TR_mean, yerr=TR_40W_std, label='EU', capsize=5)


plt.ylim(-0.05, 0.6)
plt.xlim(20, 140)

plt.ylabel('Thermal Resistance (TR) [K/W]')
plt.xlabel('Heat Input (Q) [W]')

plt.title('TR vs Q for DI Water')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(x=Q, y=di_TR_mean, label='DI_mean')

plt.errorbar(x=Q, y=di_TR_mean, yerr=TR_40W_std, label='EU', capsize=5)


plt.ylim(-0.05, 0.55)
plt.xlim(20, 140)

plt.ylabel('Thermal Resistance (TR) [K/W]')
plt.xlabel('Heat Input (Q) [W]')

plt.title('TR vs Q for DI Water')
plt.legend()
plt.show()

# %% [markdown]
# #Temperature Difference (dT) vs Heat Inputs (Q)

# %%
dT_40W_opt = df_mean_40w[df_mean_40w['dG[KJ/mol]'] == df_mean_40w['dG[KJ/mol]'].min()]
dT_60W_opt = df_mean_60w[df_mean_60w['dG[KJ/mol]'] == df_mean_60w['dG[KJ/mol]'].min()]
dT_80W_opt = df_mean_80w[df_mean_80w['dG[KJ/mol]'] == df_mean_80w['dG[KJ/mol]'].min()]
dT_100W_opt = df_mean_100w[df_mean_100w['dG[KJ/mol]'] == df_mean_100w['dG[KJ/mol]'].min()]
dT_120W_opt = df_mean_120w[df_mean_120w['dG[KJ/mol]'] == df_mean_120w['dG[KJ/mol]'].min()]

# %%
#dT_40W_opt
#dT_60W_opt
#dT_80W_opt
#dT_100W_opt
dT_120W_opt
# Out:
#      Te[K]  Tc[K]  dT[K]   P[bar]   Q[W]   TR[K/W]  alpha  beta  phase  \
# 54  337.95  312.4  25.55  0.47996  120.0  0.212917   90.0   0.0    1.0
#
#     GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 54    -2062.477415    -1906.548142 -155.929273

# %%
dT_40W_opt_idx = dT_40W_opt.index
dT_60W_opt_idx = dT_60W_opt.index
dT_80W_opt_idx = dT_80W_opt.index
dT_100W_opt_idx = dT_100W_opt.index
dT_120W_opt_idx = dT_120W_opt.index

# %%
dT_40W_opt_idx
# Out:
# Index([100], dtype='int64')

# %%
# average value of dT
dT_40W_avg = df_mean_40w['dT[K]'].mean()
dT_40W_std = df_mean_40w['dT[K]'].std()
dT_60W_avg = df_mean_60w['dT[K]'].mean()
dT_60W_std = df_mean_60w['dT[K]'].std()
dT_80W_avg = df_mean_80w['dT[K]'].mean()
dT_80W_std = df_mean_80w['dT[K]'].std()
dT_100W_avg = df_mean_100w['dT[K]'].mean()
dT_100W_std = df_mean_100w['dT[K]'].std()
dT_120W_avg = df_mean_120w['dT[K]'].mean()
dT_120W_std = df_mean_120w['dT[K]'].std()

# %%
print(f'Average dT[K]: Mean {round(dT_40W_avg,4)} +- Std {round(dT_40W_std,4)}')
print(f'Average dT[K]: Mean {round(dT_60W_avg,4)} +- Std {round(dT_60W_std,4)}')
print(f'Average dT[K]: Mean {round(dT_80W_avg,4)} +- Std {round(dT_80W_std,4)}')
print(f'Average dT[K]: Mean {round(dT_100W_avg,4)} +- Std {round(dT_100W_std,4)}')
print(f'Average dT[K]: Mean {round(dT_120W_avg,4)} +- Std {round(dT_120W_std,4)}')
# Out:
# Average dT[K]: Mean 15.7543 +- Std 5.2075
# Average dT[K]: Mean 16.9349 +- Std 4.9464
# Average dT[K]: Mean 18.5486 +- Std 5.456
# Average dT[K]: Mean 19.0671 +- Std 6.7446
# Average dT[K]: Mean 19.493 +- Std 6.4633

# %%
# critical value
dT_40W_crt = df_mean_40w[(df_mean_40w['dG[KJ/mol]'] > df_mean_40w['dG[KJ/mol]'].min()) & (df_mean_40w['Te[K]'] == df_mean_40w['Te[K]'].max())]
dT_60W_crt = df_mean_60w[(df_mean_60w['dG[KJ/mol]'] > df_mean_60w['dG[KJ/mol]'].min()) & (df_mean_60w['Te[K]'] == df_mean_60w['Te[K]'].max())]
dT_80W_crt = df_mean_80w[(df_mean_80w['dG[KJ/mol]'] > df_mean_80w['dG[KJ/mol]'].min()) & (df_mean_80w['Te[K]'] == df_mean_80w['Te[K]'].max())]
dT_100W_crt = df_mean_100w[(df_mean_100w['dG[KJ/mol]'] > df_mean_100w['dG[KJ/mol]'].min()) & (df_mean_100w['Te[K]'] == df_mean_100w['Te[K]'].max())]
dT_120W_crt = df_mean_120w[(df_mean_120w['dG[KJ/mol]'] > df_mean_120w['dG[KJ/mol]'].min()) & (df_mean_120w['Te[K]'] == df_mean_120w['Te[K]'].max())]

# %%
dT_40W_crt
# Out:
#       Te[K]     Tc[K]    dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  phase  \
# 108  340.65  316.0875  24.5625  0.579952  40.0  0.614063   90.0   0.0    1.0
#
#      GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 108    -1542.990866    -1431.733819 -111.257047

# %%
# df making of all point
di_dT_mean = [dT_40W_avg, dT_60W_avg, dT_80W_avg, dT_100W_avg, dT_120W_avg]
di_dT_crt = [dT_40W_crt['dT[K]'], dT_60W_crt['dT[K]'], dT_80W_crt['dT[K]'], dT_100W_crt['dT[K]'], dT_120W_crt['dT[K]']]
di_dT_opt = [dT_40W_opt['dT[K]'], dT_60W_opt['dT[K]'], dT_80W_opt['dT[K]'], dT_100W_opt['dT[K]'], dT_120W_opt['dT[K]']]
Q = [40, 60, 80, 100, 120]

# %%
plt.figure(figsize=(8,5))
plt.scatter(x=Q, y=di_dT_mean, label='DI_mean')
plt.scatter(x=Q, y=di_dT_opt, label='DI_opt')
plt.scatter(x=Q, y=di_dT_crt, label='DI_crt')
plt.errorbar(x=Q, y=di_dT_mean, yerr=dT_40W_std, label='EU', capsize=5)


plt.ylim(0, 30)
plt.xlim(20, 140)

plt.ylabel('Temperature difference (dT) [K]')
plt.xlabel('Heat Input (Q) [W]')

plt.title('dT vs Q for DI Water')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(x=Q, y=di_dT_mean, label='DI_mean')

plt.errorbar(x=Q, y=di_dT_mean, yerr=dT_40W_std, label='EU', capsize=5)


plt.ylim(0, 25)
plt.xlim(20, 140)

plt.ylabel('Temperature difference (dT) [K]')
plt.xlabel('Heat Input (Q) [W]')

plt.title('dT vs Q for DI Water')
plt.legend()
plt.show()

# %% [markdown]
# #TR vs Q vs dT

# %%
plt.figure(figsize=(8, 5))

# Scatter plots
plt.scatter(Q, di_TR_mean, label='DI_mean')
plt.scatter(Q, di_TR_opt, label='DI_opt')
plt.scatter(Q, di_TR_crt, label='DI_crt')

# Error bars
plt.errorbar(Q, di_TR_mean, yerr=TR_40W_std, label='EU', capsize=5)

# Axis limits
plt.ylim(-0.05, 0.55)
plt.xlim(20, 140)

# Axis labels
plt.ylabel('Thermal Resistance (TR) [K/W]')
plt.xlabel('Heat Input (Q) [W]')

# Second y-axis
ax2 = plt.twinx()
ax2.set_ylim(0, 25)
ax2.set_ylabel('Temperature Difference [K]')

# Title and legend
plt.title('TR vs Q vs dT for DI Water')
plt.legend()

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8, 5))

# Scatter plots
plt.scatter(x=Q, y=di_TR_mean, label='DI_mean')
plt.scatter(x=Q, y=di_TR_opt, label='DI_opt')
plt.scatter(x=Q, y=di_TR_crt, label='DI_crt')

# Error bars
plt.errorbar(x=Q, y=di_TR_mean, yerr=TR_40W_std, label='EU', capsize=5)

# Line plot for di_dT_mean on the second y-axis
ax2 = plt.twinx()
ax2.plot(Q, di_dT_mean, color='red', label='dT_mean')
ax2.set_ylabel('Temperature Difference')

# Axis limits
plt.ylim(0, 0.55)
plt.xlim(20, 140)
ax2.set_ylim(0, 30)

# Axis labels
plt.ylabel('Thermal Resistance (TR) [K/W]')
plt.xlabel('Heat Input (Q) [W]')

# Title and legend
plt.title('TR vs Q vs dT for DI Water')
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 5))

# Scatter plots
plt.scatter(x=Q, y=di_TR_mean, label='DI_mean')


# Error bars
plt.errorbar(x=Q, y=di_TR_mean, yerr=TR_40W_std, label='EU', capsize=5, ecolor = 'r')

# Axis limits
plt.ylim(-0.05, 0.55)
plt.xlim(20, 140)

# Axis labels
plt.ylabel('Thermal Resistance (TR) [K/W]')
plt.xlabel('Heat Input (Q) [W]')

# Second y-axis
ax2 = plt.twinx()
ax2.set_ylim(0, 25)
ax2.set_ylabel('Temperature Difference [K]')

# Title and legend
plt.title('TR vs Q vs dT for DI Water')
plt.legend()

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8, 5))

# Scatter plots
plt.scatter(x=Q, y=di_TR_mean, label='DI_mean')


# Error bars
plt.errorbar(x=Q, y=di_TR_mean, yerr=TR_40W_std, label='EU', capsize=5)

# Line plot for di_dT_mean on the second y-axis
ax2 = plt.twinx()
ax2.plot(Q, di_dT_mean, color='red', label='dT_mean')
ax2.set_ylabel('Temperature Difference')

# Axis limits
plt.ylim(0, 0.55)
plt.xlim(20, 140)
ax2.set_ylim(0, 30)

# Axis labels
plt.ylabel('Thermal Resistance (TR) [K/W]')
plt.xlabel('Heat Input (Q) [W]')

# Title and legend
plt.title('TR vs Q vs dT for DI Water')
plt.legend()

# Show the plot
plt.show()
