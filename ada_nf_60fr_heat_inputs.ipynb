# %% [markdown]
# # PHP - Pulsating Heat Pipe [AL203, 60FR, Heat Inputs]

# %%
from PyPulseHeatPipe import PulseHeatPipe
from PyPulseHeatPipe import DataVisualisation

# %%
d_40w = 'data/nf_heat_inputs_6ofr/40w/'
s_40w = 'nf_60fr_40w'
d_60w = 'data/nf_heat_inputs_6ofr/60w/'
s_60w = 'nf_60fr_60w'
d_80w = 'data/nf_heat_inputs_6ofr/80w/'
s_80w = 'nf_60fr_80w'
d_100w = 'data/nf_heat_inputs_6ofr/100w/'
s_100w = 'nf_60fr_100w'
d_120w = 'data/nf_heat_inputs_6ofr/120w/'
s_120w = 'nf_60fr_120w'

# %%
analysis_40w = PulseHeatPipe(datapath=d_40w, sample=s_40w)
analysis_60w = PulseHeatPipe(datapath=d_60w, sample=s_60w)
analysis_80w = PulseHeatPipe(datapath=d_80w, sample=s_80w)
analysis_100w = PulseHeatPipe(datapath=d_100w, sample=s_100w)
analysis_120w = PulseHeatPipe(datapath=d_120w, sample=s_120w)
# Out:
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/40w/
#
# Sample name saved as: nf_60fr_40w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/60w/
#
# Sample name saved as: nf_60fr_60w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/80w/
#
# Sample name saved as: nf_60fr_80w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/100w/
#
# Sample name saved as: nf_60fr_100w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/120w/
#
# Sample name saved as: nf_60fr_120w

# %%
df_40w, df_conv_40w = analysis_40w.data_etl(name='nf_*')
df_60w, df_conv_60w = analysis_60w.data_etl(name='nf_*')
df_80w, df_conv_80w = analysis_80w.data_etl(name='nf_*')
df_100w, df_conv_100w = analysis_100w.data_etl(name='nf_*')
df_120w, df_conv_120w = analysis_120w.data_etl(name='nf_*')
# Out:
# list of files considered for ETL:
#  ['data/nf_heat_inputs_6ofr/40w\\nf_60fr_40w.xlsx']
# ### Compiled and converted data is saved at: data/nf_heat_inputs_6ofr/40w/'nf_60fr_40w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/nf_heat_inputs_6ofr/60w\\nf_60fr_60w.xlsx']
# ### Compiled and converted data is saved at: data/nf_heat_inputs_6ofr/60w/'nf_60fr_60w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/nf_heat_inputs_6ofr/80w\\nf_60fr_80w.xlsx']
# ### Compiled and converted data is saved at: data/nf_heat_inputs_6ofr/80w/'nf_60fr_80w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/nf_heat_inputs_6ofr/100w\\nf_60fr_100w.xlsx']
# ### Compiled and converted data is saved at: data/nf_heat_inputs_6ofr/100w/'nf_60fr_100w_combined_converted_data.csv' ###
# list of files considered for ETL:
#  ['data/nf_heat_inputs_6ofr/120w\\nf_60fr_120w.xlsx']
# ### Compiled and converted data is saved at: data/nf_heat_inputs_6ofr/120w/'nf_60fr_120w_combined_converted_data.csv' ###

# %%
df_conv_40w
df_conv_60w
df_conv_80w
df_conv_100w
df_conv_120w
# Out:
#        t(min)   Te[K]   Tc[K]  dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 0    00:00:00  304.15  304.15   0.00  0.413299   120  0.000000     90     0
# 1    00:00:05  304.15  304.15   0.00  0.413299   120  0.000000     90     0
# 2    00:00:10  304.15  304.15   0.00  0.413299   120  0.000000     90     0
# 3    00:00:15  304.35  304.15   0.20  0.413299   120  0.001667     90     0
# 4    00:00:20  304.35  304.15   0.20  0.413299   120  0.001667     90     0
# ..        ...     ...     ...    ...       ...   ...       ...    ...   ...
# 596  00:49:40  388.55  383.15   5.40  2.043004   120  0.045000     90     0
# 597  00:49:45  388.55  382.90   5.65  2.043004   120  0.047083     90     0
# 598  00:49:50  387.95  383.65   4.30  2.043004   120  0.035833     90     0
# 599  00:49:55  388.75  383.40   5.35  2.043004   120  0.044583     90     0
# 600  00:50:00  389.15  383.15   6.00  2.043004   120  0.050000     90     0
#
#      phase
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 596      1
# 597      1
# 598      1
# 599      1
# 600      1
#
# [601 rows x 10 columns]

# %%
df_gfe_40w = analysis_40w.gibbs_fe(df_conv_40w)
df_gfe_60w = analysis_60w.gibbs_fe(df_conv_60w)
df_gfe_80w = analysis_80w.gibbs_fe(df_conv_80w)
df_gfe_100w = analysis_100w.gibbs_fe(df_conv_100w)
df_gfe_120w = analysis_120w.gibbs_fe(df_conv_120w)
# Out:
# Gibbs Free Energy calculated data saved at: data/nf_heat_inputs_6ofr/40w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/nf_heat_inputs_6ofr/60w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/nf_heat_inputs_6ofr/80w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/nf_heat_inputs_6ofr/100w/'gfe_combined.csv
# Gibbs Free Energy calculated data saved at: data/nf_heat_inputs_6ofr/120w/'gfe_combined.csv

# %%
df_gfe_40w
df_gfe_60w
df_gfe_80w
df_gfe_100w
df_gfe_120w
# Out:
#        t(min)   Te[K]   Tc[K]  dT[K]    P[bar]  Q[W]   TR[K/W]  alpha  beta  \
# 0    00:00:00  304.15  304.15   0.00  0.413299   120  0.000000     90     0
# 1    00:00:05  304.15  304.15   0.00  0.413299   120  0.000000     90     0
# 2    00:00:10  304.15  304.15   0.00  0.413299   120  0.000000     90     0
# 3    00:00:15  304.35  304.15   0.20  0.413299   120  0.001667     90     0
# 4    00:00:20  304.35  304.15   0.20  0.413299   120  0.001667     90     0
# ..        ...     ...     ...    ...       ...   ...       ...    ...   ...
# 596  00:49:40  388.55  383.15   5.40  2.043004   120  0.045000     90     0
# 597  00:49:45  388.55  382.90   5.65  2.043004   120  0.047083     90     0
# 598  00:49:50  387.95  383.65   4.30  2.043004   120  0.035833     90     0
# 599  00:49:55  388.75  383.40   5.35  2.043004   120  0.044583     90     0
# 600  00:50:00  389.15  383.15   6.00  2.043004   120  0.050000     90     0
#
#      phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0        1    -2234.320518    -2234.320518    0.000000
# 1        1    -2234.320518    -2234.320518    0.000000
# 2        1    -2234.320518    -2234.320518    0.000000
# 3        1    -2235.789741    -2234.320518   -1.469223
# 4        1    -2235.789741    -2234.320518   -1.469223
# ..     ...             ...             ...         ...
# 596      1     2307.870544     2275.796163   32.074382
# 597      1     2307.870544     2274.311237   33.559307
# 598      1     2304.306724     2278.766013   25.540711
# 599      1     2309.058484     2277.281088   31.777397
# 600      1     2311.434364     2275.796163   35.638202
#
# [601 rows x 13 columns]

# %%
visual_40w = DataVisualisation(datapath=d_40w, sample=s_40w)
visual_60w = DataVisualisation(datapath=d_60w, sample=s_60w)
visual_80w = DataVisualisation(datapath=d_80w, sample=s_80w)
visual_100w = DataVisualisation(datapath=d_100w, sample=s_100w)
visual_120w = DataVisualisation(datapath=d_120w, sample=s_120w)
# Out:
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/40w/
#
# Sample name saved as: nf_60fr_40w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/60w/
#
# Sample name saved as: nf_60fr_60w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/80w/
#
# Sample name saved as: nf_60fr_80w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/100w/
#
# Sample name saved as: nf_60fr_100w
# Datapath loaded for working directory: data/nf_heat_inputs_6ofr/120w/
#
# Sample name saved as: nf_60fr_120w

# %%
visual_40w.plot_all_data(df_gfe_40w)
visual_60w.plot_all_data(df_gfe_60w)
visual_80w.plot_all_data(df_gfe_80w)
visual_100w.plot_all_data(df_gfe_100w)
visual_120w.plot_all_data(df_gfe_120w)

# %%
visual_40w.plot_Te_Tc(df_gfe_40w)
visual_60w.plot_Te_Tc(df_gfe_60w)
visual_80w.plot_Te_Tc(df_gfe_80w)
visual_100w.plot_Te_Tc(df_gfe_100w)
visual_120w.plot_Te_Tc(df_gfe_120w)

# %%
#data = analysis.data_chop(df_gfe,300,400)

# %%
df_gfe_40w['Te[K]'] = df_gfe_40w['Te[K]'].round(0)
df_gfe_60w['Te[K]'] = df_gfe_60w['Te[K]'].round(0)
df_gfe_80w['Te[K]'] = df_gfe_80w['Te[K]'].round(0)
df_gfe_100w['Te[K]'] = df_gfe_100w['Te[K]'].round(0)
df_gfe_120w['Te[K]'] = df_gfe_120w['Te[K]'].round(0)

# %%
df_mean_40w, df_std_40w = analysis_40w.data_stat(df_gfe_40w.drop('t(min)', axis=1))
df_mean_60w, df_std_60w = analysis_60w.data_stat(df_gfe_60w.drop('t(min)', axis=1))
df_mean_80w, df_std_80w = analysis_80w.data_stat(df_gfe_80w.drop('t(min)', axis=1))
df_mean_100w, df_std_100w = analysis_100w.data_stat(df_gfe_100w.drop('t(min)', axis=1))
df_mean_120w, df_std_120w = analysis_120w.data_stat(df_gfe_120w.drop('t(min)', axis=1))
# Out:
# Calculated mean and standard deviation values saved at data/nf_heat_inputs_6ofr/40w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/nf_heat_inputs_6ofr/60w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/nf_heat_inputs_6ofr/80w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/nf_heat_inputs_6ofr/100w/'combined_mean.csv' and 'combined_std.csv'
# Calculated mean and standard deviation values saved at data/nf_heat_inputs_6ofr/120w/'combined_mean.csv' and 'combined_std.csv'

# %%
df_mean_40w
df_mean_60w
df_mean_80w
df_mean_100w
df_mean_120w
# Out:
#     Te[K]       Tc[K]      dT[K]    P[bar]   Q[W]   TR[K/W]  alpha  beta  \
# 0   304.0  304.150000   0.111111  0.413299  120.0  0.000926   90.0   0.0
# 1   305.0  304.328571   0.621429  0.413299  120.0  0.005179   90.0   0.0
# 2   306.0  304.400000   1.600000  0.413299  120.0  0.013333   90.0   0.0
# 3   307.0  304.400000   2.750000  0.413299  120.0  0.022917   90.0   0.0
# 4   308.0  304.775000   3.575000  0.413299  120.0  0.029792   90.0   0.0
# ..    ...         ...        ...       ...    ...       ...    ...   ...
# 81  385.0  376.807407   8.253704  1.830515  120.0  0.068781   90.0   0.0
# 82  386.0  376.435000   9.567000  1.843919  120.0  0.079725   90.0   0.0
# 83  387.0  374.962500  12.062500  1.833069  120.0  0.100521   90.0   0.0
# 84  388.0  372.287500  15.689167  1.822343  120.0  0.130743   90.0   0.0
# 85  389.0  377.745588  11.027941  1.985315  120.0  0.091900   90.0   0.0
#
#     phase  GFE_Te[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0     1.0    -2235.136753    -2234.320518   -0.816235
# 1     1.0    -2240.197409    -2235.632324   -4.565085
# 2     1.0    -2247.910829    -2236.157047  -11.753782
# 3     1.0    -2256.358860    -2236.157047  -20.201813
# 4     1.0    -2265.174196    -2238.911840  -26.262357
# ..    ...             ...             ...         ...
# 81    1.0     1920.965396     1885.180888   35.784508
# 82    1.0     1950.475900     1906.853930   43.621969
# 83    1.0     1935.368902     1880.663765   54.705137
# 84    1.0     1914.595458     1844.481663   70.113795
# 85    1.0     2209.399982     2149.647518   59.752465
#
# [86 rows x 12 columns]

# %%
analysis_40w.data_property_avg(df_mean_40w, df_std_40w)
# Out:
# Tc  average:     313.143 +- 0.2282 [K]
# P   average:     0.5093 +- 0.0018 [bar]
# dT  average:     11.8265 +- 0.2434 [K]
# TR  average:     0.2957 +- 0.0061 [K/W]
# GFE average:     -1774.5002 +- 9.2303 [KJ/mol]

# %%
analysis_60w.data_property_avg(df_mean_60w, df_std_60w)
# Out:
# Tc  average:     315.1095 +- 0.2642 [K]
# P   average:     0.4998 +- 0.0029 [bar]
# dT  average:     13.8506 +- 0.303 [K]
# TR  average:     0.2308 +- 0.0051 [K/W]
# GFE average:     -1872.3998 +- 13.3422 [KJ/mol]

# %%
analysis_80w.data_property_avg(df_mean_80w, df_std_80w)
# Out:
# Tc  average:     321.8031 +- 0.7115 [K]
# P   average:     0.5733 +- 0.0094 [bar]
# dT  average:     14.1637 +- 0.7278 [K]
# TR  average:     0.177 +- 0.0091 [K/W]
# GFE average:     -1604.6696 +- 34.7349 [KJ/mol]

# %%
analysis_100w.data_property_avg(df_mean_100w, df_std_100w)
# Out:
# Tc  average:     328.8516 +- 1.45 [K]
# P   average:     0.6793 +- 0.0175 [bar]
# dT  average:     14.6085 +- 1.5256 [K]
# TR  average:     0.1461 +- 0.0153 [K/W]
# GFE average:     -1281.6345 +- 55.8562 [KJ/mol]

# %%
analysis_120w.data_property_avg(df_mean_120w, df_std_120w)
# Out:
# Tc  average:     331.0209 +- 3.0979 [K]
# P   average:     0.8358 +- 0.07 [bar]
# dT  average:     15.4485 +- 3.1416 [K]
# TR  average:     0.1287 +- 0.0262 [K/W]
# GFE average:     -815.2401 +- 161.827 [KJ/mol]

# %%
analysis_40w.best_TP(df_mean_40w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-88.7154]
# Tc optimal:        316.15[K]
# Te optimal:        332.0[K]
# P  optimal:        0.5133[bar]
# dT optimal:        16.0[K]
# TR optimal:        0.4[K/W]
# GFE optimal:       dG(332.0, 0.5133) = -1752.9603 [KJ/mol]

# %%
analysis_60w.best_TP(df_mean_60w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-104.6213]
# Tc optimal:        316.7214[K]
# Te optimal:        334.0[K]
# P  optimal:        0.48[bar]
# dT optimal:        17.1429[K]
# TR optimal:        0.2857[K/W]
# GFE optimal:       dG(334.0, 0.48) = -1932.9214 [KJ/mol]

# %%
analysis_80w.best_TP(df_mean_80w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-134.6454]
# Tc optimal:        319.0875[K]
# Te optimal:        341.0[K]
# P  optimal:        0.48[bar]
# dT optimal:        22.0625[K]
# TR optimal:        0.2758[K/W]
# GFE optimal:       dG(341.0, 0.48) = -1947.3613 [KJ/mol]

# %%
analysis_100w.best_TP(df_mean_100w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-159.8962]
# Tc optimal:        317.8167[K]
# Te optimal:        344.0[K]
# P  optimal:        0.48[bar]
# dT optimal:        26.2[K]
# TR optimal:        0.262[K/W]
# GFE optimal:       dG(344.0, 0.48) = -1939.6056 [KJ/mol]

# %%
analysis_120w.best_TP(df_mean_120w)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-140.0571]
# Tc optimal:        311.65[K]
# Te optimal:        333.0[K]
# P  optimal:        0.4466[bar]
# dT optimal:        20.9[K]
# TR optimal:        0.1742[K/W]
# GFE optimal:       dG(333.0, 0.4466) = -2088.4585 [KJ/mol]

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'Tc[K]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'Tc[K]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'Tc[K]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'Tc[K]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'Tc[K]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'dT[K]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'dT[K]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'dT[K]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'dT[K]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'dT[K]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'P[bar]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'P[bar]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'P[bar]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'P[bar]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'P[bar]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'TR[K/W]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'TR[K/W]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'TR[K/W]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'TR[K/W]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'TR[K/W]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'GFE_Tc[KJ/mol]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'GFE_Tc[KJ/mol]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'GFE_Tc[KJ/mol]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'GFE_Tc[KJ/mol]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'GFE_Tc[KJ/mol]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'GFE_Te[KJ/mol]')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'GFE_Te[KJ/mol]')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'GFE_Te[KJ/mol]')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'GFE_Te[KJ/mol]')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'GFE_Te[KJ/mol]')

# %%
visual_40w.plot_eu(df_mean_40w, df_std_40w, 'dG[KJ/mol]','.r','g')
visual_60w.plot_eu(df_mean_60w, df_std_60w, 'dG[KJ/mol]','.r','g')
visual_80w.plot_eu(df_mean_80w, df_std_80w, 'dG[KJ/mol]','.r','g')
visual_100w.plot_eu(df_mean_100w, df_std_100w, 'dG[KJ/mol]','.r','g')
visual_120w.plot_eu(df_mean_120w, df_std_120w, 'dG[KJ/mol]','.r','g')
