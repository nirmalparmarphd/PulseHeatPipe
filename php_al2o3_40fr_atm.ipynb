# %% [markdown]
# # PHP - Pulsating Heat Pipe [AL2O3, 40FR, Atm]

# %%
from analysis import PulseHeatPipe
from analysis import DataVisualisation

# %%
analysis = PulseHeatPipe("data/al2o3_diwater_exp_atm/40_FR/")
# Out:
# Data loaded from directory: data/al2o3_diwater_exp_atm/40_FR/

# %%
df, df_conv = analysis.data_etl()
# Out:
# Compiled and converted data is saved at: data/al2o3_diwater_exp_atm/40_FR/'combined_converted_data.csv'

# %%
df_gfe = analysis.gibbs_fe(df_conv)
# Out:
# Gibbs Free Energy calculated data saved at: data/al2o3_diwater_exp_atm/40_FR/'gfe_combined.csv

# %%
df_gfe
# Out:
#      t(min)   Te[K]   Tc[K]  dT[K]    P[bar]   TR[K/W]  GFE[KJ/mol]
# 0       0.0  300.48  298.90   1.58  1.013250  0.019792    32.882594  \
# 1       0.5  300.48  299.15   1.33  1.013250  0.016667    32.882594
# 2       1.0  302.82  299.15   3.67  1.013250  0.045833    33.138669
# 3       1.5  303.82  299.90   3.92  1.013250  0.048958    33.248102
# 4       2.0  305.48  299.90   5.58  1.013250  0.069792    33.429762
# ..      ...     ...     ...    ...       ...       ...          ...
# 96     48.0  369.48  341.65  27.83  1.699859  0.347917  1629.760029
# 97     48.5  369.48  342.15  27.33  1.699859  0.341667  1629.760029
# 98     49.0  369.48  342.90  26.58  1.699859  0.332292  1629.760029
# 99     49.5  368.82  342.40  26.42  1.699859  0.330208  1626.848798
# 100    50.0  369.82  343.15  26.67  1.699859  0.333333  1631.259754
#
#      GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0         32.709689    0.172905
# 1         32.737047    0.145547
# 2         32.737047    0.401621
# 3         32.819123    0.428980
# 4         32.819123    0.610639
# ..              ...         ...
# 96      1507.003123  122.756906
# 97      1509.208601  120.551428
# 98      1512.516818  117.243211
# 99      1510.311340  116.537458
# 100     1513.619557  117.640197
#
# [101 rows x 9 columns]

# %%
visual = DataVisualisation('AL203_DI_40FR_Atm')
# Out:
# Data loaded from directory: AL203_DI_40FR_Atm

# %%
visual.plot_all_data(df_gfe)

# %%
visual.plot_Te_Tc(df_gfe)

# %%
df_selected =  analysis.data_chop(df_gfe)
# Out:
# Optimal range of temperature(Te) for data selection: [Tmin:300.48, Tmax:370]

# %%
df_mean, df_std = analysis.data_stat(df_selected)
# Out:
# Calculated mean and standard deviation values saved at data/al2o3_diwater_exp_atm/40_FR/'combined_mean.csv' and 'combined_std.csv'

# %%
df_mean
# Out:
#      Te[K]     t(min)    Tc[K]   dT[K]    P[bar]   TR[K/W]  GFE[KJ/mol]
# 0   300.48   0.250000  299.025   1.455  1.013250  0.018230    32.882594  \
# 1   302.82   1.000000  299.150   3.670  1.013250  0.045833    33.138669
# 2   303.82   1.500000  299.900   3.920  1.013250  0.048958    33.248102
# 3   305.48   2.000000  299.900   5.580  1.013250  0.069792    33.429762
# 4   308.15   2.500000  299.900   8.250  1.013250  0.103125    33.721949
# ..     ...        ...      ...     ...       ...       ...          ...
# 70  368.48  41.666667  332.400  36.080  1.503431  0.451042  1236.577887
# 71  368.82  48.250000  341.400  27.420  1.699859  0.342708  1626.848798
# 72  369.15  38.500000  327.650  41.500  1.405217  0.518750  1044.087292
# 73  369.48  46.125000  338.775  30.705  1.626199  0.383854  1483.575184
# 74  369.82  50.000000  343.150  26.670  1.699859  0.333333  1631.259754
#
#     GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0        32.723368    0.159226
# 1        32.737047    0.401621
# 2        32.819123    0.428980
# 3        32.819123    0.610639
# 4        32.819123    0.902827
# ..             ...         ...
# 70     1119.849573  116.728314
# 71     1505.900384  120.948414
# 72      926.710555  117.376737
# 73     1364.390091  119.185093
# 74     1513.619557  117.640197
#
# [75 rows x 9 columns]

# %%
analysis.data_property_avg(df_mean, df_std)
# Out:
# Tc  average:     318.0263 +- 3.4251 [K]
# P   average:     1.2791 +- 0.0642 [bar]
# dT  average:     27.8753 +- 3.4251 [K]
# TR  average:     0.3484 +- 0.0428 [K/W]
# GFE average:     698.1779 +- 127.9364 [KJ/mol]

# %%
analysis.best_TP(df_mean)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[0.1592]
# Te optimal:        300.48[K]
# P  optimal:        1.0132[bar]
# dT optimal:        1.455[K]
# TR optimal:        0.0182[K/W]
# GFE optimal:       dG(300.48, 1.0132) = 32.8826 [KJ/mol]

# %%
visual.plot_eu(df_mean, df_std, 'Tc[K]')

# %%
visual.plot_eu(df_mean, df_std, 'dT[K]')

# %%
visual.plot_eu(df_mean, df_std, 'P[bar]')

# %%
visual.plot_eu(df_mean, df_std, 'TR[K/W]')

# %%
visual.plot_eu(df_mean, df_std, 'GFE[KJ/mol]')

# %%
visual.plot_eu(df_mean, df_std, 'dG[KJ/mol]','.r','g')
