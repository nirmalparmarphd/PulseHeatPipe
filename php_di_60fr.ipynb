# %% [markdown]
# # PHP - Pulsating Heat Pipe [DI, 60FR]

# %%
from analysis import PulseHeatPipe
from analysis import DataVisualisation

# %%
analysis = PulseHeatPipe("data/di_water_exp/60_FR/")
# Out:
# Data loaded from directory: data/di_water_exp/60_FR/

# %%
df, df_conv = analysis.data_etl()
# Out:
# Compiled and converted data is saved at: data/di_water_exp/60_FR/'combined_converted_data.csv'

# %%
df_gfe = analysis.gibbs_fe(df_conv)
# Out:
# Gibbs Free Energy calculated data saved at: data/di_water_exp/60_FR/'gfe_combined.csv

# %%
df_gfe
# Out:
#      t(min)       Te[K]   Tc[K]  ...  GFE[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0       0.0  298.150000  296.65  ... -2190.243835    -2179.224665  -11.019171
# 1       0.5  297.816667  296.65  ... -2187.795131    -2179.224665   -8.570466
# 2       1.0  298.150000  296.40  ... -2190.243835    -2177.388136  -12.855699
# 3       1.5  300.150000  296.40  ... -2204.936063    -2177.388136  -27.547927
# 4       2.0  302.150000  296.40  ... -2219.628291    -2177.388136  -42.240154
# ..      ...         ...     ...  ...          ...             ...         ...
# 460    58.0  364.950000  342.90  ...    39.937775       37.524765    2.413010
# 461    58.5  364.550000  342.40  ...    39.894002       37.470049    2.423953
# 462    59.0  364.550000  342.40  ...    39.894002       37.470049    2.423953
# 463    59.5  364.750000  342.65  ...    39.915888       37.497407    2.418482
# 464    60.0  364.950000  342.65  ...    39.937775       37.497407    2.440368
#
# [464 rows x 9 columns]

# %%
visual = DataVisualisation('DI_WATER_60FR')
# Out:
# Data loaded from directory: DI_WATER_60FR

# %%
visual.plot_all_data(df_gfe)

# %%
visual.plot_Te_Tc(df_gfe)

# %%
df_selected = analysis.data_chop(df_gfe)
# Out:
# Optimal range of temperature(Te) for data selection: [Tmin:297.8167, Tmax:369]

# %%
df_mean, df_std = analysis.data_stat(df_selected)
# Out:
# Calculated mean and standard deviation values saved at data/di_water_exp/60_FR/'combined_mean.csv' and 'combined_std.csv'

# %%
df_mean
# Out:
#           Te[K]  t(min)   Tc[K]  ...  GFE[KJ/mol]  GFE_Tc[KJ/mol]  dG[KJ/mol]
# 0    300.150000    1.50  296.40  ... -2204.936063    -2177.388136  -27.547927
# 1    302.150000    2.00  296.40  ... -2219.628291    -2177.388136  -42.240154
# 2    302.816667    2.50  296.65  ... -2224.525700    -2179.224665  -45.301035
# 3    303.150000    0.25  303.15  ... -1850.096252    -1850.096252    0.000000
# 4    303.750000    0.00  303.15  ... -2443.723685    -2438.896577   -4.827109
# ..          ...     ...     ...  ...          ...             ...         ...
# 223  366.816667   45.10  348.80  ...   652.535560      620.720063   31.815498
# 224  367.150000   50.00  348.75  ...   747.471898      709.250597   38.221301
# 225  367.483333   49.00  351.90  ...   702.294560      672.513372   29.781188
# 226  367.816667   50.00  352.40  ...   702.931591      673.468918   29.462673
# 227  368.816667   49.50  352.40  ...   704.842683      673.468918   31.373765
#
# [228 rows x 9 columns]

# %%
analysis.data_property_avg(df_mean, df_std)
# Out:
# Tc  average:     322.9413 +- 1.5978 [K]
# P   average:     0.7389 +- 0.0686 [bar]
# dT  average:     19.6166 +- 1.5978 [K]
# TR  average:     0.2452 +- 0.02 [K/W]
# GFE average:     -1010.5159 +- 224.7014 [KJ/mol]

# %%
analysis.best_TP(df_mean)
# Out:
# Optimal G(T,P) condition at lowest (optimal) dG[-142.4012]
# Te optimal:        328.4833[K]
# P  optimal:        0.48[bar]
# dT optimal:        23.3333[K]
# TR optimal:        0.2917[K/W]
# GFE optimal:       dG(328.4833, 0.48) = -2004.7032 [KJ/mol]

# %%
visual.plot_eu(df_mean, df_std, 'Tc[K]')

# %%
visual.plot_eu(df_mean, df_std, 'dT[K]')

# %%
visual.plot_eu(df_mean, df_std, 'P[bar]')

# %%
visual.plot_eu(df_mean, df_std, 'TR[K/W]')

# %%
visual.plot_eu(df_mean, df_std, 'GFE[KJ/mol]')

# %%
visual.plot_eu(df_mean, df_std, 'dG[KJ/mol]','.r','g')
